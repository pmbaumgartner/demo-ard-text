# %% [markdown]
# ## Article Collection and Volume Reduction Pipeline
# 1. Find efficient keywords with word embeddings (gensim)
# 2. Remove duplicitous articles with cosine similarity on TFIDF vectors (scikit-learn)
# 3. **Remove duplicitous articles with entity extraction and jaccard similarity** (spacy)
# 4. Classify relevant articles (scikit-learn)

# %% [markdown]
# ## Summary
# Using the article summary, we calculate the jaccard similarity between the set of entities in two articles. In practice, for each pair of articles, if their similarity is above a threshold, we remove one. We also change the threshold depending on the size of the entity set.

# %%
import pandas as pd
import numpy as np
import spacy

# %%
usecols=['Article_ID', 'Title', 'Summary']
data = pd.read_csv('../data/nyt_ftpg_1996_2006_no_text.csv', engine='python', usecols=usecols)

# %%
data.head()
# Out:
#    Article_ID                                              Title  \
# 0           1  Nation's Smaller Jails Struggle To Cope With S...
# 1           2             Dancing (and Kissing) In the New Year
# 2           3   Forbes's Silver Bullet for the Nation's Malaise
# 3           4  Up at Last, Bridge to Bosnia Is Swaying Gatewa...
# 4           5  2 SIDES IN SENATE DISAGREE ON PLAN TO END FURL...
#
#                                              Summary
# 0          Jails overwhelmed with hardened criminals
# 1                               new years activities
# 2                 Steve Forbes running for President
# 3  U.S. military constructs bridge to help their ...
# 4  Democrats and Republicans can't agree on plan ...

# %%
nlp = spacy.load('en')

# %%
# %%time
# entity extraction (with multithreading) in spacy

entities = []
for index, doc in enumerate(nlp.pipe(data['Summary'].tolist(), n_threads=-1)):
    doc_ents = set(ent.text for ent in doc.ents)
    if len(doc_ents) > 0:
        entities.append((index, doc_ents))
# Out:
# CPU times: user 1min 47s, sys: 8.77 s, total: 1min 56s
# Wall time: 1min 21s

# %%
len(entities)
# Out:
# 19586

# %%
entities[:5]
# Out:
# [(1, {'new years'}),
#  (2, {'Steve Forbes'}),
#  (3, {'Bosnia', 'U.S.'}),
#  (4, {'Democrats', 'Republicans'}),
#  (5, {'Interstate Commerce Commission'})]

# %%
# jaccard takes a long time. we'll run on a limited set
limited_entities = entities[:5000]

# %% [markdown]
# ## Jaccard Index / Similarity
# ![jaccard](https://wikimedia.org/api/rest_v1/media/math/render/svg/eaef5aa86949f49e7dc6b9c8c3dd8b233332c9e7)
# ![jaccardimg](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Intersection_of_sets_A_and_B.svg/400px-Intersection_of_sets_A_and_B.svg.png)

# %%
def jaccard(a, b):
    if len(a) == 0 or len(b) == 0:
        return 0
    else:
        c = a.intersection(b)
        return float(len(c)) / (len(a) + len(b) - len(c))

# %%
# %%time

# there are better ways to do this (vectorize)

n_statements = len(limited_entities)
jc_similarities = []

for i, (ent_ix, ents) in enumerate(limited_entities):
    entities_subset = limited_entities[i:]
    for j, (ent_c_ix, ents_comparison) in enumerate(entities_subset):
        scs = 1 if j == 0 else jaccard(ents, ents_comparison)
        jc_similarities.append(scs)

jc_empty = np.zeros((n_statements, n_statements))
upper_indices = np.triu_indices(n_statements)
jc_empty[upper_indices] = jc_similarities
jaccard_sim_matrix = np.triu(jc_empty, -1).T + jc_empty
# Out:
# CPU times: user 21.8 s, sys: 1.16 s, total: 23 s
# Wall time: 25.3 s

# %%
jaccard_sim_matrix[np.diag_indices((n_statements))] = 0

# %%
kept_indices = [i[0] for i in limited_entities]
similarities = pd.DataFrame(jaccard_sim_matrix, index=kept_indices, columns=kept_indices)

# %%
def highlight_nonzero(val):
    color = 'yellow' if val > 0 else 'white'
    return f'background-color: {color}'

similarities.loc[:20,:20].style.applymap(highlight_nonzero)
# Out:
# <style  type="text/css" >
#     #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col0 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col1 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col2 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col3 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col4 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col5 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col6 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col7 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col8 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col9 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row0_col10 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col0 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col1 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col2 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col3 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col4 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col5 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col6 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col7 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col8 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col9 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row1_col10 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row2_col0 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row2_col1 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row2_col2 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row2_col3 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row2_col4 {
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row5_col2 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row5_col3 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row5_col4 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row5_col5 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row5_col6 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row5_col7 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row5_col8 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row5_col9 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row5_col10 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col0 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col1 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col2 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col3 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col4 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col5 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col6 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col7 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col8 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col9 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row6_col10 {
#             background-color:  white;
#         }    #T_c8c4db5e_4e19_11e8_9537_acbc329802e3row7_col0 {
#             background-color:  white;
#         }    #T_c8c

# %%
ix = 3
reference_document_index, reference_entities = limited_entities[ix]
print("Ref:", data.loc[reference_document_index, 'Summary'], sep="\t")
print(reference_entities)
print()

most_similar_indices = similarities[reference_document_index].sort_values(ascending=False).head()
for index, value in most_similar_indices.iteritems():
    print(round(value, 2), data.loc[index, 'Summary'], sep="\t")
    print([ent[1] for ent in limited_entities if ent[0] == index])
# Out:
# Ref:	Democrats and Republicans can't agree on plan to end furloughs
# {'Republicans', 'Democrats'}
#
# 1.0	Republicans and Democrats raise record amounts of money despite talks about campaign finance reform
# [{'Democrats', 'Republicans'}]
# 1.0	Democrats attack Republicans on campaign finance abuses
# [{'Republicans', 'Democrats'}]
# 0.67	Unlike Democrats, Republicans upbeat about fall campaigns
# [{'about fall', 'Republicans', 'Democrats'}]
# 0.67	Contrary to Republicans, Democrats call for quick resolution of House impeachment proceedings
# [{'House', 'Democrats', 'Republicans'}]
# 0.5	Democrats support unpopular Senator for racial reasons
# [{'Democrats'}]
